# %% [markdown]
# 触发登录按钮
# https://zhihu-web-analytics.zhihu.com/api/v2/za/logs/batch
#
#
#
#
# 中文验证码
# https://www.zhihu.com/api/v3/oauth/captcha?lang=cn
#     数据：-----------------------------144544791012
# Content-Disposition: form-data; name="input_text"
#
# {"img_size":[200,44],"input_points":[[10,26.0333251953125],[31,22.0333251953125],[69,32.0333251953125]]}
# -----------------------------144544791012--
#
# 英文验证码
# https://www.zhihu.com/api/v3/oauth/captcha?lang=en
# JSON数据{"error":{"message":"请提交正确的验证码 :(","code":120000,"name":"ERR_VERITY_CAPTCHA"}}

# %% [markdown]
# 英文验证码信息：{"img_base64":"\n"}

# %% [markdown]
# 中文验证码信息：
# {"img_base64":"\n"}

# %% [markdown]
# # 作者源代码分析

# %%
import urllib.request
import re
import ssl
import urllib.parse
import http.cookiejar
import base64
import json
import hmac
from hashlib import sha1
import time

#防止SSL出现问题，加上以下代码
ssl._create_default_https_context = ssl._create_unverified_context
print("Cookie处理中")
# 进行登录操作
url1 = ""
req0 = urllib.request.Request(url1)
req0.add_header("User-Agent","")
req0data = urllib.request.urlopen(req0).read().decode("utf-8","ignore")

# 验证码处理
oauth = "" # 值由分析获得
yzm1 = "" # 验证码网址
req0.add_header('User-Agent','')
req0.add_header('authorization','oauth'+str(oauth))
req0data = urllib.request.urlopen(req0).read().decode()
YZM1 = ''
req0 = urllib.request.Request(yzm1,method='PUT') # Put 方式是从抓包工具获取
req0data  urllib.request.urlopen(req0).read().decode('utf-8','ignore')
pat_yzm = 'img_base64":"(.*?)"'
yzm_data = re.compile(pat_yzm,re.S).findall(req0data)
if(len(yzm_data)>0):
    yzm_data = yzm_data[0]
    # 解码生成图片
    yzm_img = base64.b64decode(yzm_data.replace("\\n","")) # 注意这里\\n是分析图片和袁发送的比较获得
    fh = open("./知乎验证码")
    fh.write(yzm_img)
    fh.close()
else:
    yzm_data = ""
yzm_type = input("请输入验证码类型:(1)倒立图片,(2)直接输入")
yzm_map = { # 这里的坐标是不断地试出来的，大多都是固定
    1:[22,796875, 22],
    2:[42,796875, 22],
    3:[63,796875, 21],
    4:[84,796875, 20],
    5:[107,796875,20],
    6:[129,796875,22],
    7:[150,796875,22]
}
if(yzm_type=="1"):
    yzm_id = input("请输入倒立图片")
    captcha = {
        'img_size':[200,44],
        'input_points':[],
    }
    yzm_id = eval(yzm_id)
    for num in yzm_id:
        captcha['input_points'].append(yzm_map[num])
    yzm_value = json.dumps(captcha)
else:
    yzm_value = json.dumps(captcha)
# 验证码验证
yzmposturl = ""
yzmpostdata = urllib.parse.urlencode({
    'input_text':yzm_value,
}).encode('utf-8')
req1 = urllib.request.Request(yzmposturl,yzmpostdata)
req1.add_header('User-Agent','')
req1data = urllib.request.urlopen(req1),read().decode('utf-8','ignore')

# 签名处理：通过阅读原网站的加密js代码，模拟加密
def get_signature(grantType, clientId, source, timestamp):
    hm = hmac.new(b'',None,sha1)
    hm.update(str.encode(grantType))
    hm.updata(str.encode(clientId))
    hm.updata(str.encode(str(timestamp)))
    return str(hm.hexdigest())
# 账号密码验证
timestamp = int(time.time()*1000)
loginposturl = ""
loginpostdata = urllib.parse.urlencdoe({
    "client_id":"",
    "grant_type":"password",
    "timestamp":timestamp,
    "source":"",
    "signature":get_signature("pasword","","")
    "username":"+86",
    "password":"",
    "captcha":yzm_value,
    "lang":"en",
    "ref_source":"other_",
    "utm_source":"",
}).encode("utf-8")
req2 = urllib.request.Request(loginposturl,loginpostdata)
req2.add_header('User-Agent','')
req2data = urllib.request.urlopen(req2).read().decode("utf-8","ignore")

# 登录成功以后爬取
url = ""
req0 = urllib.request.Request(url)
req0.add_header('User-Agent','')
req0data = urllib.request.urlopen(req0).read().decode("utf-8","ignore")
#。。。主要是分析上面的处理代码
